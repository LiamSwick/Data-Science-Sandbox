# %% [markdown]
# <a href="https://colab.research.google.com/github/LiamSwick/Data-Science-Sandbox/blob/main/Species%2BSegmentation%2Bwith%2BCluster%2BAnalysis%2BPart%2B1_%2BExercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Species Segmentation with Cluster Analysis

# %% [markdown]
# The Iris flower dataset is one of the most popular ones for machine learning. You can read a lot about it online and have probably already heard of it: https://en.wikipedia.org/wiki/Iris_flower_data_set
#
# We didn't want to use it in the lectures, but believe that it would be very interesting for you to try it out (and maybe read about it on your own).
#
# There are 4 features: sepal length, sepal width, petal length, and petal width.
#
# Start by creating 2 clusters. Then standardize the data and try again. Does it make a difference?
#
# Use the Elbow rule to determine how many clusters are there.

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from google.colab import drive
drive.mount('/content/drive')
sns.set()
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'iris_dataset.csv'</i>.

# %%
df = pd.read_csv('/content/drive/MyDrive/iris_dataset.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# ## Plot the data

# %% [markdown]
# For this exercise, try to cluster the iris flowers by the shape of their sepal.
#
# <i> Use the 'sepal_length' and 'sepal_width' variables.</i>

# %%
plt.scatter(df["sepal_width"],df["sepal_length"])
plt.xlabel("sepal_width")
plt.ylabel("sepal_length")
plt.show()

# %% [markdown]
# # Clustering (unscaled data)

# %% [markdown]
# Separate the original data into 2 clusters.

# %%
kmeans = KMeans(2)
kmeans.fit(df[["sepal_width","sepal_length"]])
# Out:
# KMeans(n_clusters=2)

# %%
clusters = kmeans.predict(df[["sepal_width","sepal_length"]])
df["Cluster"] = clusters
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  Cluster
# 0           5.1          3.5           1.4          0.2        1
# 1           4.9          3.0           1.4          0.2        1
# 2           4.7          3.2           1.3          0.2        1
# 3           4.6          3.1           1.5          0.2        1
# 4           5.0          3.6           1.4          0.2        1

# %%
plt.scatter(df["sepal_width"],df["sepal_length"],c=df["Cluster"],cmap="rainbow")

# %% [markdown]
# # Standardize the variables

# %% [markdown]
# Import and use the <i> method </i> function from sklearn to standardize the data.

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(df[["sepal_width","sepal_length"]])

# %% [markdown]
# # Clustering (scaled data)

# %%
kmeans = KMeans(2)
kmeans.fit(x_scaled)
# Out:
# KMeans(n_clusters=2)

# %%
clusters = kmeans.predict(x_scaled)
df["Cluster"] = clusters
#df.head()

# %%
plt.scatter(df["sepal_width"],df["sepal_length"],c=df["Cluster"],cmap="rainbow")

# %% [markdown]
# ## Take Advantage of the Elbow Method

# %% [markdown]
# ### WCSS

# %%
wcss = []
for i in range(1,10):
  kmeans = KMeans(i)
  kmeans.fit(x_scaled)
  holder = kmeans.inertia_
  wcss.append(holder)
wcss
# Out:
# [300.00000000000006,
#  168.39262198361095,
#  103.78443895265744,
#  88.69373224472108,
#  62.07205418976128,
#  52.12057513457867,
#  45.16057775600414,
#  43.6568162920939,
#  31.93783073286813]

# %% [markdown]
# ### The Elbow Method

# %%
plt.plot(range(1,10),wcss)
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
# Out:
# Text(0, 0.5, 'WCSS')

# %% [markdown]
# How many clusters are there?
