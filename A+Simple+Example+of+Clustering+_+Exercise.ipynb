# %% [markdown]
# <a href="https://colab.research.google.com/github/LiamSwick/Data-Science-Sandbox/blob/main/A%2BSimple%2BExample%2Bof%2BClustering%2B_%2BExercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A Simple Example of Clustering

# %% [markdown]
# You are given much more country data. Using the same methodology as the one in the lecture, group all the countries in 2 clusters.
#
# Try with other numbers of clusters and see if they match your expectations. Maybe 7 is going to be a cool one!
#
# Plot the data using the <i> c </i> parameter to separate the data by the clusters we defined.
#
# <i> Note: c stands for color <i>

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'Countries.csv'</i>.

# %%
df = pd.read_csv('/content/drive/MyDrive/Countries-exercise (1).csv')
df.head()
# Out:
#           name  Longitude   Latitude
# 0        Aruba -69.982677  12.520880
# 1  Afghanistan  66.004734  33.835231
# 2       Angola  17.537368 -12.293361
# 3     Anguilla -63.064989  18.223959
# 4      Albania  20.049834  41.142450

# %% [markdown]
# ## Plot the data

# %% [markdown]
# Plot the <i>'Longtitude'</i> and <i>'Latitude'</i> columns.

# %%
plt.scatter(df['Longitude'], df['Latitude'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Select the features

# %% [markdown]
# Create a copy of that data and remove all parameters apart from <i>Longitude</i> and <i>Latitude</i>.

# %%
subset = df[['Longitude', 'Latitude']]
subset.head()
# Out:
#    Longitude   Latitude
# 0 -69.982677  12.520880
# 1  66.004734  33.835231
# 2  17.537368 -12.293361
# 3 -63.064989  18.223959
# 4  20.049834  41.142450

# %% [markdown]
# ## Clustering

# %% [markdown]
# Assume there are only two clusters.

# %%
kmeans = KMeans(2)
kmeans.fit(subset)

# %%
clusters = kmeans.fit_predict(subset)

# %% [markdown]
# ### Clustering Resutls

# %%
df["Cluster"] = clusters
df.head()
# Out:
#           name  Longitude   Latitude  Cluster
# 0        Aruba -69.982677  12.520880        1
# 1  Afghanistan  66.004734  33.835231        0
# 2       Angola  17.537368 -12.293361        0
# 3     Anguilla -63.064989  18.223959        1
# 4      Albania  20.049834  41.142450        0

# %%
plt.scatter(df['Longitude'], df['Latitude'], c=df['Cluster'], cmap='rainbow')

# %% [markdown]
# Did you remember to use the <i> c </i> parameter to separate the data by the clusters we defined?

# %%
kmeans = KMeans(7)
kmeans.fit(subset)
clusters = kmeans.fit_predict(subset)
df["Cluster"] = clusters
plt.scatter(df['Longitude'], df['Latitude'], c=df['Cluster'], cmap='rainbow')

# %% [markdown]
# If you haven't, go back and play around with the number of clusters.
#
# Try 3, 7 and 8 and see if the results match your expectations!
